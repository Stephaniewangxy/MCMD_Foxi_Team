# %% [markdown]
# **<font>Import the Dataset and have an overview**<font>

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
data=pd.read_csv('NCAA_data.csv')
data
# Out:
#       team1_id  team1_score  team2_id  team2_score WLoc  num_ot  \
# 0       1192.0           82    1341.0           76    N       0
# 1       1125.0           81    1396.0           70    N       0
# 2       1295.0           78    1300.0           74    N       0
# 3       1113.0           74    1385.0           65    N       0
# 4       1278.0           86    1257.0           76    N       0
# 5       1261.0           79    1463.0           74    N       0
# 6       1120.0           78    1308.0           77    N       0
# 7       1437.0           61    1388.0           57    N       0
# 8       1196.0           70    1305.0           61    N       0
# 9       1459.0           84    1371.0           68    N       0
# 10      1242.0           87    1318.0           53    N       0
# 11      1345.0           61    1330.0           48    N       0
# 12      1199.0           76    1436.0           69    N       0
# 13      1276.0           74    1285.0           55    N       0
# ...

# %%
data.tail()
# Out:
#       team1_id  team1_score  team2_id  team2_score WLoc  num_ot  \
# 1162    1260.0           78    1243.0           62    N       0
# 1163    1276.0           58    1199.0           54    N       0
# 1164    1437.0           95    1242.0           79    N       0
# 1165    1276.0           69    1260.0           57    N       0
# 1166    1437.0           79    1276.0           62    N       0
#
#      team1_position team2_position  team1_seed  team2_seed  \
# 1162            W12            W04          12           4
# 1163            X01            X08           1           8
# 1164            X01            X08           1           8
# 1165            Y05            Y04           5           4
# 1166            Y05            Y04           5           4
#
#              ...          team1_adjoe  team1_de team1_adjde team2_tempo  \
# 1162         ...                108.7      96.2        93.9        66.6
# 1163         ...                111.2      92.7        96.5        72.6
# ...

# %%
data['WLoc'].value_counts()  #What is WLoc???
# Out:
# N    1167
# Name: WLoc, dtype: int64

# %%
data.shape #1167 Records with 104 columns
# Out:
# (1167, 104)

# %% [markdown]
# **<font>Extract team1_id and team2_id with frequncy<font>**

# %%
a=data['team1_id'].value_counts()

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
b=data['team2_id'].value_counts()

# %%
c=b.to_frame()

# %%
c.to_csv('team2frequency.csv')

# %% [markdown]
# **<font> Plot Seed number with frequncies<font>**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data['team1_seed'],label="Count")
plt.show()

# %%
sns.countplot(data['team2_seed'],label="Count")
plt.show()

# %%
data['seed_diff']=data['team1_seed']-data['team2_seed']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        3
# 5      -11
# 6       -7
# 7       -5
# 8        3
# 9       -3
# 10      -9
# 11     -11
# 12      -9
# 13     -13
# 14     -13
# 15     -13
# 16     -15
# 17       1
# 18       7
# 19      -5
# 20       3
# 21       1
# 22       9
# 23       1
# 24     -15
# 25     -15
# 26     -15
# 27     -13
# 28     -11
# 29     -11
#         ..
# 1137    -7
# 1138    -7
# 1139   -13
# 1140   -13
# 1141    -9
# 1142    -9
# 1143    -5
# 1144    -5
# 1145    -8
# 1146    -8
# 1147    -8
# 1148    -8
# 1149    -5
# 1150    -5
# 1151    -8
# 1152    -8
# 1153     8
# 1154     8
# 1155     8
# 1156     8
# 1157    -8
# 1158    -8
# 1159     8
# 1160     8
# 1161     8
# 1162     8
# 1163    -7
# 1164    -7
# 1165     1
# 1166     1
# Name: seed_diff, Length: 1167, dtype: int64

# %%
sns.countplot(data['seed_diff'],label="Count")
plt.show()

# %% [markdown]
# **<font>Tryinng to find is there any two teams met more than 1 time.<font>**

# %%
data["Group"] = data["team1_id"].astype(str) + data["team2_id"].astype(str)

# %%
data.head()
# Out:
#    team1_id  team1_score  team2_id  team2_score WLoc  num_ot team1_position  \
# 0    1192.0           82    1341.0           76    N       0           X16a
# 1    1125.0           81    1396.0           70    N       0           W11a
# 2    1295.0           78    1300.0           74    N       0           W16a
# 3    1113.0           74    1385.0           65    N       0           X11a
# 4    1278.0           86    1257.0           76    N       0            W10
#
#   team2_position  team1_seed  team2_seed      ...       team1_de  team1_adjde  \
# 0           X16b          16          16      ...       104.7090     110.5500
# 1           W11b          11          11      ...        99.6691     101.8860
# 2           W16b          16          16      ...       110.0540     109.8730
# 3           X11b          11          11      ...        99.8027      98.6844
# 4            W07          10           7      ...       101.4670      96.3335
#
# ...

# %%
data['Group'].value_counts()
# Out:
# 1196.01417.0    4
# 1242.01314.0    3
# 1314.01437.0    3
# 1314.01277.0    3
# 1314.01116.0    3
# 1211.01199.0    2
# 1458.01332.0    2
# 1196.01438.0    2
# 1181.01277.0    2
# 1246.01153.0    2
# 1277.01268.0    2
# 1277.01181.0    2
# 1266.01246.0    2
# 1332.01329.0    2
# 1242.01228.0    2
# 1458.01112.0    2
# 1417.01153.0    2
# 1112.01211.0    2
# 1211.01452.0    2
# 1403.01211.0    2
# 1246.01428.0    2
# 1326.01235.0    2
# 1139.01330.0    2
# 1314.01344.0    2
# 1314.01449.0    2
# 1305.01400.0    2
# 1276.01397.0    2
# 1326.01172.0    2
# 1276.01196.0    2
# 1207.01125.0    2
#                ..
# 1268.01222.0    1
# 1268.01355.0    1
# 1196.01338.0    1
# 1448.01433.0    1
# 1196.01345.0    1
# 1424.01458.0    1
# 1397.01269.0    1
# 1462.01340.0    1
# 1314.01233.0    1
# 1140.01233.0    1
# 1196.01173.0    1
# 1325.01378.0    1
# 1211.01422.0    1
# 1276.01199.0    1
# 1228.01361.0    1
# 1192.01341.0    1
# 1338.01160.0    1
# 1328.01354.0    1
# 1257.01129.0    1
# ...

# %%
groupby season team1 比赛次数

# %% [markdown]
# **<font>Add result and team1_win columns.<font>**

# %%
data['result']=data.team1_score - data.team2_score

# %%
data
# Out:
#       team1_id  team1_score  team2_id  team2_score WLoc  num_ot  \
# 0       1192.0           82    1341.0           76    N       0
# 1       1125.0           81    1396.0           70    N       0
# 2       1295.0           78    1300.0           74    N       0
# 3       1113.0           74    1385.0           65    N       0
# 4       1278.0           86    1257.0           76    N       0
# 5       1261.0           79    1463.0           74    N       0
# 6       1120.0           78    1308.0           77    N       0
# 7       1437.0           61    1388.0           57    N       0
# 8       1196.0           70    1305.0           61    N       0
# 9       1459.0           84    1371.0           68    N       0
# 10      1242.0           87    1318.0           53    N       0
# 11      1345.0           61    1330.0           48    N       0
# 12      1199.0           76    1436.0           69    N       0
# 13      1276.0           74    1285.0           55    N       0
# ...

# %%
data[data['result']<0]
# Out:
# Empty DataFrame
# ...

# %%
data['team1_win'] = data['result'].map(lambda x: (x>0 and 1) or (x<0 and 0))

# %%
data[data['team1_win']==0]
# Out:
# Empty DataFrame
# ...

# %%
data.groupby('team1_id')

# %%
data.sort_values(['team1_id','team2_id']) ## To see each team in team1 have met which team before
# Out:
#       team1_id  team1_score  team2_id  team2_score WLoc  num_ot  \
# 68      1104.0           86    1194.0           78    N       0
# 226     1104.0           70    1390.0           67    N       0
# 242     1104.0           80    1393.0           71    N       0
# 1110    1104.0           86    1439.0           83    N       0
# 834     1107.0           71    1291.0           64    N       0
# 771     1112.0           81    1125.0           64    N       0
# 550     1112.0           71    1156.0           57    N       0
# 687     1112.0           93    1181.0           77    N       0
# 164     1112.0           96    1211.0           95    N       2
# 878     1112.0           84    1211.0           61    N       0
# 803     1112.0           74    1217.0           51    N       0
# 655     1112.0           77    1272.0           75    N       0
# 1039    1112.0          100    1315.0           82    N       0
# 180     1112.0           88    1323.0           71    N       0
# ...

# %%
seed1team=data[data['team1_seed']==1]['team1_id']

# %%
S1T=seed1team.to_frame()

# %%
S1T
# Out:
#       team1_id
# 16      1211.0
# 24      1181.0
# 25      1438.0
# 26      1314.0
# 36      1211.0
# 45      1314.0
# 47      1181.0
# 48      1438.0
# 52      1181.0
# 54      1211.0
# 56      1438.0
# 62      1438.0
# 65      1438.0
# 66      1438.0
# 73      1245.0
# 74      1246.0
# 77      1326.0
# 78      1332.0
# 103     1242.0
# 104     1245.0
# 113     1356.0
# 114     1400.0
# 135     1143.0
# 136     1163.0
# 139     1228.0
# 140     1242.0
# 153     1257.0
# 154     1268.0
# 175     1268.0
# 176     1277.0
# ...        ...
# 1045    1292.0
# 1046    1321.0
# 1051    1438.0
# 1052    1452.0
# 1055    1116.0
# 1056    1124.0
# 1059    1242.0
# 1060    1246.0
# 1063    1277.0
# 1064    1314.0
# 1067    1376.0
# 1068    1417.0
# 1073    1196.0
# 1074    1211.0
# 1077    1458.0
# 1078    1462.0
# 1079    1124.0
# 1080    1242.0
# 1087    1332.0
# 1088    1462.0
# 1091    1314.0
# 1092    1376.0
# 1117    1196.0
# 1118    1437.0
# 1135    1267.0
# 1136    1437.0
# ...

# %%
S1T['team1_id'].value_counts()
# Out:
# 1314.0    14
# 1242.0    13
# 1181.0    10
# 1458.0    10
# 1277.0    10
# 1438.0     9
# 1246.0     8
# 1393.0     8
# 1452.0     6
# 1272.0     6
# 1338.0     6
# 1257.0     6
# 1112.0     5
# 1268.0     5
# 1211.0     5
# 1326.0     5
# 1276.0     5
# 1163.0     5
# 1455.0     5
# 1401.0     4
# 1196.0     4
# 1437.0     4
# 1462.0     4
# 1301.0     4
# 1328.0     4
# 1228.0     4
# 1332.0     4
# 1417.0     4
# 1139.0     4
# 1266.0     3
#           ..
# 1356.0     1
# 1292.0     1
# 1156.0     1
# 1388.0     1
# 1130.0     1
# 1373.0     1
# 1267.0     1
# 1116.0     1
# 1113.0     1
# 1281.0     1
# 1387.0     1
# 1177.0     1
# 1143.0     1
# 1243.0     1
# 1241.0     1
# 1165.0     1
# 1386.0     1
# 1274.0     1
# 1378.0     1
# 1321.0     1
# 1153.0     1
# 1334.0     1
# 1325.0     1
# 1195.0     1
# 1221.0     1
# 1397.0     1
# 1307.0     1
# 1435.0     1
# 1231.0     1
# 1299.0     1
# Name: team1_id, Length: 76, dtype: int64

# %% [markdown]
# **<font>Pythagorean Expected Winning Percentage<font>**

# %%
data['exp_win1'] = (data['team1_adjoe']**11.5)/ ((data['team1_adjde']**11.5)+(data['team1_adjoe']**11.5))
data['exp_win2'] = (data['team2_adjoe']**11.5)/ ((data['team2_adjde']**11.5)+(data['team2_adjoe']**11.5))

# %%
#adjoe:An estimate of the offensive efficiency (points scored per 100 possessions) a team would have against the average D-I defense.
#adjed:An estimate of the defensive efficiency (points allowed per 100 possessions) a team would have against the average D-I offense

# %% [markdown]
# **<font>Log5 prediction for A's chance of winning<font>**

# %%
data['team1_log5'] = (data['exp_win1'] - (data['exp_win1']*data['exp_win2']))/ (data['exp_win1']+data['exp_win2']-(2*data['exp_win1']*data['exp_win2']))

# %%
data[['team1_adjoe','team1_teamname','season','team2_teamname','team1_adjde','exp_win1','exp_win2','team1_log5']].head()
# Out:
#    team1_adjoe team1_teamname  season team2_teamname  team1_adjde  exp_win1  \
# 0      106.296    F Dickinson    2019   Prairie View     110.5500  0.389061
# 1      114.952        Belmont    2019         Temple     101.8860  0.800207
# 2      106.675    N Dakota St    2019     NC Central     109.8730  0.415885
# 3      109.886     Arizona St    2019      St John's      98.6844  0.774944
# 4      110.803      Minnesota    2019     Louisville      96.3335  0.833312
#
#    exp_win2  team1_log5
# 0  0.382990    0.506403
# 1  0.738939    0.585922
# 2  0.208404    0.730051
# 3  0.721882    0.570190
# 4  0.913200    0.322116

# %% [markdown]
# **<font>Logistic Regression with ANOVA and MultinomiaNB & SVM with confusion matrix<font>**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import numpy as np
import pandas as pd
from sklearn.externals import joblib
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (auc, classification_report, roc_auc_score, accuracy_score,
                             f1_score, log_loss, roc_curve, confusion_matrix, precision_score, recall_score)
from sklearn.preprocessing import StandardScaler
from math import sin, cos, sqrt, atan2, radians
import random
import statsmodels.api as sm

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(DF[['team1_log5']], DF[['team1_win']] , test_size=0.33, random_state=109)

# %%
def train_predict_evaluate_model(classifier, 
                                 X_train, y_train, 
                                 X_test, y_test):
    # build model    
    classifier.fit(X_train, y_train)
    # predict using model
    predictions = classifier.predict(X_test) 
    # evaluate model prediction performance   
    get_metrics(true_labels=y_test, 
                predicted_labels=predictions)
    return predictions

# %%
from sklearn import metrics

# define a function to evaluate our classification models based on four metrics
def get_metrics(true_labels, predicted_labels):
    
    print ('Accuracy:', np.round(                                                    
                        metrics.accuracy_score(true_labels, 
                                               predicted_labels),
                        2))
    print ('Precision:', np.round(
                        metrics.precision_score(true_labels, 
                                               predicted_labels),
                        2))
    print ('Recall:', np.round(
                        metrics.recall_score(true_labels, 
                                               predicted_labels),
                        2))
    print ('F1 Score:', np.round(
                        metrics.f1_score(true_labels, 
                                               predicted_labels),
                        2))

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier

mnb = MultinomialNB()
svm = SGDClassifier(loss='hinge', max_iter=100)

# Multinomial Naive Bayes with bag of words features
predictions = train_predict_evaluate_model(classifier=logit,
                                           X_train=X_train,
                                           y_train=y_train,
                                           X_test=X_test,
                                           y_test=y_test)
# Out:
# Accuracy: 0.74
# Precision: 0.72
# Recall: 0.74
# F1 Score: 0.73
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
logit = LogisticRegression()
logit.fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
smlogit = sm.Logit(y_train, X_train).fit()
smlogit.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.667876
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              team1_win   No. Observations:                 1563
# Model:                          Logit   Df Residuals:                     1562
# Method:                           MLE   Df Model:                            0
# Date:                Tue, 11 Feb 2020   Pseudo R-squ.:                 0.03628
# Time:                        23:23:57   Log-Likelihood:                -1043.9
# converged:                       True   LL-Null:                       -1083.2
#                                         LLR p-value:                       nan
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
data_pred=pd.DataFrame()

# %%
data_pred['preds'] = logit.predict_proba(scaler.fit_transform(X_test))[:,1]
data_pred['prediction'] = logit.predict(scaler.fit_transform(X_test))

# %%
data_pred['team1_win']=y_test.reset_index(drop=True)
data_pred['team1_log5']=X_test.reset_index(drop=True)

# %%
data_pred.head()
# Out:
#       preds  prediction  team1_log5  team1_win
# 0  0.000058           0    0.116461          0
# 1  0.036951           0    0.446542          1
# 2  0.006919           0    0.359763          1
# 3  0.207449           0    0.544210          0
# 4  0.941266           1    0.753500          1

# %%
confusion_matrix(data_pred['team1_win'], data_pred['prediction'])
# Out:
# array([[352,  46],
#        [169, 204]])

# %%
f1_score(data_pred['team1_win'],data_pred['prediction'])
# Out:
# 0.6548956661316212

# %%
log_loss(data_pred['team1_win'].values, data_pred['preds'].values)
# Out:
# 0.933480246377388

# %% [markdown]
# **<font> Dataset Combination<font>**

# %%
data2=pd.DataFrame()

# %%
data2['team1_id']=data['team2_id']

# %%
data2['team2_id']=data['team1_id']

# %%
data2['team2_adjoe']=data['team1_adjoe']

# %%
data2['team1_adjoe']=data['team2_adjoe']

# %%
data2['team2_adjde']=data['team1_adjde']

# %%
data2['team1_adjde']=data['team2_adjde']

# %%
data2['exp_win2']=data['exp_win1']

# %%
data2['exp_win1']=data['exp_win2']

# %%
data2['team1_log5']=1-data['team1_log5']

# %%
data2['team1_win']=data['team1_win']-1

# %%
data2['team1_score']=data['team2_score']

# %%
data2['team1_pt_school_ncaa']=data['team2_pt_school_ncaa']

# %%
data2['team1_seed']=data['team2_seed']

# %%
data1=pd.DataFrame()

# %%
data1['team1_id']=data['team1_id']

# %%
data1['team2_id']=data['team2_id']

# %%
data1['team2_adjoe']=data['team2_adjoe']

# %%
data1['team1_adjoe']=data['team1_adjoe']

# %%
data1['team2_adjde']=data['team2_adjde']

# %%
data1['team1_adjde']=data['team1_adjde']

# %%
data1['exp_win2']=data['exp_win2']

# %%
data1['exp_win1']=data['exp_win1']

# %%
data1['team1_log5']=data['team1_log5']

# %%
data1['team1_win']=data['team1_win']

# %%
data1['team1_score']=data['team1_score']

# %%
data1['team1_pt_school_ncaa']=data['team1_pt_school_ncaa']

# %%
data1['team1_seed']=data['team1_seed']

# %%
data1.head()
# Out:
#    team1_id  team2_id  team2_adjoe  team1_adjoe  team2_adjde  team1_adjde  \
# 0    1192.0    1341.0     101.6550      106.296     105.9590     110.5500
# 1    1125.0    1396.0     108.9910      114.952      99.5630     101.8860
# 2    1295.0    1300.0      96.7551      106.675     108.6610     109.8730
# 3    1113.0    1385.0     109.7820      109.886     101.0440      98.6844
# 4    1278.0    1257.0     113.5030      110.803      92.4983      96.3335
#
#    exp_win2  exp_win1  team1_log5  team1_win  team1_score
# 0  0.382990  0.389061    0.506403          1           82
# 1  0.738939  0.800207    0.585922          1           81
# 2  0.208404  0.415885    0.730051          1           78
# 3  0.721882  0.774944    0.570190          1           74
# 4  0.913200  0.833312    0.322116          1           86

# %%
data2.head()
# Out:
#    team1_id  team2_adjoe  team1_adjoe  team2_adjde  team1_adjde  exp_win2  \
# 0    1341.0      106.296     101.6550     110.5500     105.9590  0.389061
# 1    1396.0      114.952     108.9910     101.8860      99.5630  0.800207
# 2    1300.0      106.675      96.7551     109.8730     108.6610  0.415885
# 3    1385.0      109.886     109.7820      98.6844     101.0440  0.774944
# 4    1257.0      110.803     113.5030      96.3335      92.4983  0.833312
#
#    exp_win1  team1_log5  team2_id  team1_win  team1_score
# 0  0.382990    0.493597    1192.0          0           76
# 1  0.738939    0.414078    1125.0          0           70
# 2  0.208404    0.269949    1295.0          0           74
# 3  0.721882    0.429810    1113.0          0           65
# 4  0.913200    0.677884    1278.0          0           76

# %%
DF=data1.append(data2,ignore_index=True)

# %%
DF.head()
# Out:
#    exp_win1  exp_win2  team1_adjde  team1_adjoe  team1_id  team1_log5  \
# 0  0.389061  0.382990     110.5500      106.296    1192.0    0.506403
# 1  0.800207  0.738939     101.8860      114.952    1125.0    0.585922
# 2  0.415885  0.208404     109.8730      106.675    1295.0    0.730051
# 3  0.774944  0.721882      98.6844      109.886    1113.0    0.570190
# 4  0.833312  0.913200      96.3335      110.803    1278.0    0.322116
#
#    team1_pt_school_ncaa  team1_score  team1_seed  team1_win  team2_adjde  \
# 0                   1.0           82          16          1     105.9590
# 1                   7.0           81          11          1      99.5630
# 2                   1.0           78          16          1     108.6610
# 3                   1.0           74          11          1     101.0440
# 4                   1.0           86          10          1      92.4983
#
#    team2_adjoe  team2_id
# 0     101.6550    1341.0
# 1     108.9910    1396.0
# 2      96.7551    1300.0
# ...

# %% [markdown]
# **<font> Plot the bubble chart to see the correlation between seed No. and score and to figure out the team with higher NCAA apperances<font>**

# %%
from matplotlib import pyplot as plt
fig,ax=plt.subplots(figsize=(10,5))

DF=DF[1:]
frequency=DF.groupby('team1_id')["team1_pt_school_ncaa"].mean()
team1=DF['team1_id'].unique()
seed=DF.groupby('team1_id')["team1_seed"].mean()
score=DF.groupby('team1_id')["team1_score"].mean()

ax.scatter(seed,score,s=frequency,alpha=0.6)
ax.set(xlim=(0,17),ylim=(25,110),\
       xlabel="seed number",\
       ylabel="score",\
       title="seed No. & score of each team ")
for i,j,z in zip(seed,score,team1):
    ax.text(x=i-0.3,y=j-0.1,s=z,fontsize=5)
ax.spines["top"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.show()
